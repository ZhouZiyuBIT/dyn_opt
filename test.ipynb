# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
p = np.linspace(0,0.99,10000)
y1 = -np.log((1-p))
y2 = -np.log((1-p)*(1-p))
y3 = -np.log((1-p*p))
y4 = 0.1*(1/(1-p)-1)
plt.plot(p, y1, label='y1')
plt.plot(p, y2, label='y2')
plt.plot(p, y3, label='y3')
plt.plot(p, y4, label='y4')
plt.legend()

# %%
x = np.linspace(-10,10,1000)
y1 = np.exp(-x*x/1)
y2 = np.exp(-x*x/2)
y3 = np.exp(-x*x/8)
y4 = np.exp(-x*x/16)

plt.plot(x, y1, label='y1')
plt.plot(x, y2, label='y2')
plt.plot(x, y3, label='y3')
plt.plot(x, y4, label='y4')
plt.legend()
